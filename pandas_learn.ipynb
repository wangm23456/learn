# %% [markdown]
# ## packages

# %%
from pandas import Series,DataFrame
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline
import plotly
import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls

# %%
plotly.tools.set_credentials_file(username='wangm23456',api_key='z1gz6bdzo1')

# %% [markdown]
# ## csv

# %%
data1=pd.read_csv('/home/inat/桌面/output/data1.csv',error_bad_lines=False,warn_bad_lines=False)
data1=data1[((data1.name=='gamma') |(data1.name=='e-'))&(data1.energy>0)]

# %%
data1
# Out:
#         name    energy        px       py        pz        dx        dy  \
# 0      gamma  21.89070 -2.068730 -49.7500  0.407815 -0.015983 -0.999844
# 1      gamma   5.37679  0.010917 -49.7500  0.185422 -0.067662 -0.997414
# 2      gamma  17.94690 -0.390152 -49.7500 -3.234420  0.053446 -0.992069
# 3      gamma   5.37679 -0.738743 -49.7500 -0.606525 -0.074159 -0.996603
# 4      gamma  20.24010 -2.697120 -49.7500 -0.295988 -0.055019 -0.997979
# 5      gamma   6.36271  2.089370 -49.7500  1.573110  0.019231 -0.999113
# 6      gamma   6.36271  2.039200 -49.7500 -0.711950  0.027707 -0.996395
# 7      gamma   7.01695  2.879410 -49.7500  1.282920  0.041198 -0.995509
# 8      gamma   5.37679  1.509210 -49.7500  2.142250 -0.007545 -0.999970
# 9      gamma   6.36271 -1.345040 -49.7500 -0.232297 -0.017173 -0.999823
# 10     gamma  16.66090 -1.467190 -49.7500  2.554010 -0.029158 -0.999571
# 11     gamma   5.90740 -0.158685 -49.7500  1.183310 -0.010686 -0.999517
# ...

# %%
data1.to_csv('/home/inat/桌面/output/data1.csv',index=False)

# %%
data1.dtypes
# Out:
# name       object
# energy    float64
# px        float64
# py        float64
# pz        float64
# dx        float64
# dy        float64
# dz        float64
# id          int64
# pid         int64
# eid         int64
# pox         int64
# poy         int64
# poz         int64
# dtype: object

# %%
! pip install plotly --upgrade
# Out:
# Requirement already up-to-date: plotly in /home/inat/APP/anaconda3/lib/python3.5/site-packages
# Requirement already up-to-date: requests in /home/inat/APP/anaconda3/lib/python3.5/site-packages (from plotly)
# Requirement already up-to-date: six in /home/inat/APP/anaconda3/lib/python3.5/site-packages (from plotly)
# Requirement already up-to-date: pytz in /home/inat/APP/anaconda3/lib/python3.5/site-packages (from plotly)

# %% [markdown]
# ## 切片

# %%
data2=data1.ix[:,("name","energy")]

# %%
data2=data2[data2.name.isin(['e-'])]

# %%
data2
# Out:
#       name     energy
# 152     e-   5.996920
# 282     e-   1.463210
# 1084    e-   3.544150
# 1353    e-   0.534545
# 1384    e-  13.454000
# 1474    e-   0.394652
# 2201    e-   7.922310
# 2745    e-   1.920280
# 4141    e-  13.295600
# 5375    e-  11.091300
# 5402    e-   3.136280
# 5454    e-   0.507288
# 5498    e-   3.732240
# 5499    e-   0.040099
# 6119    e-   2.812040
# 6335    e-   2.379170
# 7238    e-   6.061980
# 7256    e-   1.009360
# 7315    e-   2.547420
# 7521    e-  11.455300
# 8100    e-   8.492200
# 8423    e-   9.657740
# 9056    e-   0.795229
# 9167    e-   3.542850
# 9499    e-   8.311830
# 9608    e-  17.986800
# 10866   e-   4.467400
# 10959   e-   4.001270
# 11023   e-   4.751580
# 11026   e-   4.086260
# ...    ...        ...
# 24495   e-   4.194950
# 24973   e-   6.183820
# 25037   e-   3.348030
# 25368   e-   5.252630
# 25383   e-   0.980307
# 25456   e-   2.427510
# 25740   e-   5.711200
# 25983   e-   1.430980
# 26257   e-   6.792920
# ...

# %% [markdown]
# ## 图

# %%
plt.figure()

# %%
data1['energy'].plot.hist(bins=200,figure=400)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-57-865b161457e8> in <module>()
# ----> 1 data1['energy'].plot.hist(bins=200,figure=400)
#
# /home/inat/APP/anaconda3/lib/python3.5/site-packages/pandas/tools/plotting.py in hist(self, bins, **kwds)
#    3652         axes : matplotlib.AxesSubplot or np.array of them
#    3653         """
# -> 3654         return self(kind='hist', bins=bins, **kwds)
#    3655
#    3656     def kde(self, **kwds):
#
# /home/inat/APP/anaconda3/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3564                            colormap=colormap, table=table, yerr=yerr,
# ...

# %%
data1.energy.plot.box()

# %%
type(data1.name[30])
# Out:
# str

# %%
data1.name[30]
# Out:
# 'gamma'

# %%
help(DataFrame.plot)
# Out:
# Help on class FramePlotMethods in module pandas.tools.plotting:
#
# class FramePlotMethods(BasePlotMethods)
#  |  DataFrame plotting accessor and method
#  |
#  |  Examples
#  |  --------
#  |  >>> df.plot.line()
#  |  >>> df.plot.scatter('x', 'y')
#  |  >>> df.plot.hexbin()
#  |
#  |  These plotting methods can also be accessed by calling the accessor as a
#  |  method with the ``kind`` argument:
#  |  ``df.plot(kind='line')`` is equivalent to ``df.plot.line()``
#  |
#  |  Method resolution order:
#  |      FramePlotMethods
#  |      BasePlotMethods
#  |      pandas.core.base.PandasObject
#  |      pandas.core.base.StringMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
# ...

# %% [markdown]
# ## 六边形图

# %%
data1.plot.hexbin(x='px',y='pz',gridsize=25)

# %% [markdown]
# ## 饼图

# %%
data1.name.plot.pie(figsize=(6,6))

# %%
iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-330ffa06eb6b> in <module>()
# ----> 1 iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
#
# NameError: name 'iplot' is not defined

# %%
py.iplot(data1)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-54-22d9fcd771f9> in <module>()
# ----> 1 py.iplot(data1)
#
# /home/inat/APP/anaconda3/lib/python3.5/site-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     149     if 'auto_open' not in plot_options:
#     150         plot_options['auto_open'] = False
# --> 151     url = plot(figure_or_data, **plot_options)
#     152
#     153     if isinstance(figure_or_data, dict):
#
# /home/inat/APP/anaconda3/lib/python3.5/site-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     210
#     211     """
# --> 212     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     213
#     214     for entry in figure['data']:
#
# ...

# %%
data1['energy']
# Out:
# 0        21.89070
# 1         5.37679
# 2        17.94690
# 3         5.37679
# 4        20.24010
# 5         6.36271
# 6         6.36271
# 7         7.01695
# 8         5.37679
# 9         6.36271
# 10       16.66090
# 11        5.90740
# 12        5.66019
# 13       24.65790
# 14        5.37679
# 15       11.14140
# 16        6.34985
# 17        6.34985
# 18       22.27230
# 19       14.50400
# 20        6.36271
# 21        6.36271
# 22        6.36271
# 23        5.36786
# 24        6.34985
# 25       20.96970
# 26        6.34985
# 27        9.11124
# 28        5.35682
# 29       22.17450
#            ...
# 29872     6.36271
# 29873     5.37679
# 29874    21.09430
# 29875     6.36271
# 29876     5.37679
# 29877    31.80410
# 29878     5.90740
# 29879    33.56250
# 29880    29.14620
# 29881     5.37679
# 29882     5.37679
# 29883     5.37679
# 29884    29.78160
# 29885     9.89689
# 29886    34.23830
# 29887    21.95630
# 29888     9.50050
# 29889     6.36271
# 29890     6.34985
# ...
